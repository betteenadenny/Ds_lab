# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd

df = pd.read_csv('6diabetes.csv')
df.plot.scatter('Age','BMI',c='Glucose',colormap='viridis') 
X, y = df[['Age','BMI']],df['Outcome']

# x_train, x_test, y_train, y_test = train_test_split(X, y,train_size=0.7) 
classifier =KNeighborsClassifier(n_neighbors=3) 
classifier.fit(X,y)

# result = classifier.predict(x_test)
# accuracy = accuracy_score(y_test, result) * 100
# print(f'Accuracy is {accuracy}')

features = [[float(i) for i in input(f'Enter bmi,age').split()]] 
result = classifier.predict(features)
print(result)
if result == 0:
    print('Not diabetic')
else:
    print('Diabetic')
# Out:
# [1]
# Diabetic
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

df = pd.read_csv('6diabetes.csv')
X,y = df[['BMI','Age']],df['Outcome']
 
df.plot.scatter('Age','BMI',c="Outcome",colormap='viridis')

mode1 = KNeighborsClassifier(n_neighbors=3)
mode1.fit(X,y)

features = [[ float(i) for i in input(f"Enter bmi and age").split()]]
print(mode1.predict(features))
# Out:
# [0]
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
